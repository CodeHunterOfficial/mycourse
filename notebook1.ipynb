# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
x = np.linspace(0, 10, 100) # Create an array of 100 numbers from 0 to 10
y = np.sin(x) # Calculate the sine of each value in x

# Create a plot
plt.figure(figsize=(8, 5)) # Set the figure size
plt.plot(x, y, label="sin(x)", color='blue') # Plot the data
plt.title("Simple Plot of Sine Wave") # Add a title
plt.xlabel("x") # Label the x-axis
plt.ylabel("y") # Label the y-axis
plt.legend() # Show the legend
plt.grid(True, alpha=0.3) # Add a grid for better readability
plt.show() # Display the plot
